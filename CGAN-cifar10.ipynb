# %% [markdown]
# <a href="https://colab.research.google.com/github/shru1010/GANs/blob/main/CGAN-cifar10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
"""

Based on the code by Jason Brownlee from his blogs on https://machinelearningmastery.com/
I seriously urge everyone to foloow his blogs and get enlightened.
I am adapting his code to various applications but original credit goes to Jason.

Conditional GAN that generates images using a random latent vector and corresponding label as input.
Conditional GANs can be used to supply a label during taining so the latent vector
can be associated with a specific label - making the generation of images predictable.

Following code trains and generates images based on the mnist digits dataset.

"""

from numpy import zeros
from numpy import ones
from numpy.random import randn
from numpy.random import randint
from keras.datasets.cifar10 import load_data
from keras.optimizers import Adam
from keras.models import Model
from keras.layers import Input
from keras.layers import Dense
from keras.layers import Reshape
from keras.layers import Flatten
from keras.layers import Conv2D
from keras.layers import Conv2DTranspose
from keras.layers import LeakyReLU
from keras.layers import Dropout
from keras.layers import Embedding
from keras.layers import Concatenate

from matplotlib import pyplot as plt

# %%
########################################################################

#Load data and plot to get a quick understanding
#CIFAR10 classes are: airplane, automobile, bird, cat, deer, dog, frog, horse,
# ship, truck

(trainX, trainy), (testX, testy) = load_data()

# plot 25 images
for i in range(25):
	plt.subplot(5, 5, 1 + i)
	plt.axis('off')
	plt.imshow(trainX[i])
plt.show()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 [==============================] - 4s 0us/step

# %%
#############################################################################
#Define generator, discriminator, gan and other helper functions
#We will use functional way of defining model as we have multiple inputs;
#both images and corresponding labels.
########################################################################

# define the standalone discriminator model
#Given an input image, the Discriminator outputs the likelihood of the image being real.
#Binary classification - true or false (1 or 0). So using sigmoid activation.

#Unlike regular GAN here we are also providing number of classes as input.
#Input to the model will be both images and labels.
def define_discriminator(in_shape=(32,32,3), n_classes=10):

    # label input
	in_label = Input(shape=(1,))  #Shape 1
	# embedding for categorical input
    #each label (total 10 classes for cifar), will be represented by a vector of size 50.
    #This vector of size 50 will be learnt by the discriminator
	li = Embedding(n_classes, 50)(in_label) #Shape 1,50
	# scale up to image dimensions with linear activation
	n_nodes = in_shape[0] * in_shape[1]  #32x32 = 1024.
	li = Dense(n_nodes)(li)  #Shape = 1, 1024
	# reshape to additional channel
	li = Reshape((in_shape[0], in_shape[1], 1))(li)  #32x32x1


	# image input
	in_image = Input(shape=in_shape) #32x32x3
	# concat label as a channel
	merge = Concatenate()([in_image, li]) #32x32x4 (4 channels, 3 for image and the other for labels)

	# downsample: This part is same as unconditional GAN upto the output layer.
    #We will combine input label with input image and supply as inputs to the model.
	fe = Conv2D(128, (3,3), strides=(2,2), padding='same')(merge) #16x16x128
	fe = LeakyReLU(alpha=0.2)(fe)
	# downsample
	fe = Conv2D(128, (3,3), strides=(2,2), padding='same')(fe) #8x8x128
	fe = LeakyReLU(alpha=0.2)(fe)
	# flatten feature maps
	fe = Flatten()(fe)  #8192  (8*8*128=8192)
	# dropout
	fe = Dropout(0.4)(fe)
	# output
	out_layer = Dense(1, activation='sigmoid')(fe)  #Shape=1

	# define model
    ##Combine input label with input image and supply as inputs to the model.
	model = Model([in_image, in_label], out_layer)
	# compile model
	opt = Adam(lr=0.0002, beta_1=0.5)
	model.compile(loss='binary_crossentropy', optimizer=opt, metrics=['accuracy'])
	return model

test_discr = define_discriminator()
print(test_discr.summary())
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 1)]          0           []
#
#  embedding (Embedding)          (None, 1, 50)        500         ['input_1[0][0]']
#
#  dense (Dense)                  (None, 1, 1024)      52224       ['embedding[0][0]']
#
#  input_2 (InputLayer)           [(None, 32, 32, 3)]  0           []
#
#  reshape (Reshape)              (None, 32, 32, 1)    0           ['dense[0][0]']
#
#  concatenate (Concatenate)      (None, 32, 32, 4)    0           ['input_2[0][0]',
#                                                                   'reshape[0][0]']
#
#  conv2d (Conv2D)                (None, 16, 16, 128)  4736        ['concatenate[0][0]']
#
#  leaky_re_lu (LeakyReLU)        (None, 16, 16, 128)  0           ['conv2d[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 8, 8, 128)    147584      ['leaky_re_lu[0][0]']
#
#  leaky_re_lu_1 (LeakyReLU)      (None, 8, 8, 128)    0           ['conv2d_1[0][0]']
#
#  flatten (Flatten)              (None, 8192)         0           ['leaky_re_lu_1[0][0]']
#
#  dropout (Dropout)              (None, 8192)         0           ['flatten[0][0]']
#
#  dense_1 (Dense)                (None, 1)            8193        ['dropout[0][0]']
#
# ==================================================================================================
# Total params: 213,237
# Trainable params: 213,237
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None
# /usr/local/lib/python3.10/dist-packages/keras/optimizers/legacy/adam.py:117: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)

# %%
# define the standalone generator model
#latent vector and label as inputs

def define_generator(latent_dim, n_classes=10):

	# label input
	in_label = Input(shape=(1,))  #Input of dimension 1
	# embedding for categorical input
    #each label (total 10 classes for cifar), will be represented by a vector of size 50.
	li = Embedding(n_classes, 50)(in_label) #Shape 1,50

	# linear multiplication
	n_nodes = 8 * 8  # To match the dimensions for concatenation later in this step.
	li = Dense(n_nodes)(li) #1,64
	# reshape to additional channel
	li = Reshape((8, 8, 1))(li)


	# image generator input
	in_lat = Input(shape=(latent_dim,))  #Input of dimension 100

	# foundation for 8x8 image
    # We will reshape input latent vector into 8x8 image as a starting point.
    #So n_nodes for the Dense layer can be 128x8x8 so when we reshape the output
    #it would be 8x8x128 and that can be slowly upscaled to 32x32 image for output.
    #Note that this part is same as unconditional GAN until the output layer.
    #While defining model inputs we will combine input label and the latent input.
	n_nodes = 128 * 8 * 8
	gen = Dense(n_nodes)(in_lat)  #shape=8192
	gen = LeakyReLU(alpha=0.2)(gen)
	gen = Reshape((8, 8, 128))(gen) #Shape=8x8x128
	# merge image gen and label input
	merge = Concatenate()([gen, li])  #Shape=8x8x129 (Extra channel corresponds to the label)
	# upsample to 16x16
	gen = Conv2DTranspose(128, (4,4), strides=(2,2), padding='same')(merge) #16x16x128
	gen = LeakyReLU(alpha=0.2)(gen)
	# upsample to 32x32
	gen = Conv2DTranspose(128, (4,4), strides=(2,2), padding='same')(gen) #32x32x128
	gen = LeakyReLU(alpha=0.2)(gen)
	# output
	out_layer = Conv2D(3, (8,8), activation='tanh', padding='same')(gen) #32x32x3
	# define model
	model = Model([in_lat, in_label], out_layer)
	return model   #Model not compiled as it is not directly trained like the discriminator.

test_gen = define_generator(100, n_classes=10)
print(test_gen.summary())
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_4 (InputLayer)           [(None, 100)]        0           []
#
#  input_3 (InputLayer)           [(None, 1)]          0           []
#
#  dense_3 (Dense)                (None, 8192)         827392      ['input_4[0][0]']
#
#  embedding_1 (Embedding)        (None, 1, 50)        500         ['input_3[0][0]']
#
#  leaky_re_lu_2 (LeakyReLU)      (None, 8192)         0           ['dense_3[0][0]']
#
#  dense_2 (Dense)                (None, 1, 64)        3264        ['embedding_1[0][0]']
#
#  reshape_2 (Reshape)            (None, 8, 8, 128)    0           ['leaky_re_lu_2[0][0]']
#
#  reshape_1 (Reshape)            (None, 8, 8, 1)      0           ['dense_2[0][0]']
#
#  concatenate_1 (Concatenate)    (None, 8, 8, 129)    0           ['reshape_2[0][0]',
#                                                                   'reshape_1[0][0]']
#
#  conv2d_transpose (Conv2DTransp  (None, 16, 16, 128)  264320     ['concatenate_1[0][0]']
#  ose)
#
#  leaky_re_lu_3 (LeakyReLU)      (None, 16, 16, 128)  0           ['conv2d_transpose[0][0]']
#
#  conv2d_transpose_1 (Conv2DTran  (None, 32, 32, 128)  262272     ['leaky_re_lu_3[0][0]']
#  spose)
#
#  leaky_re_lu_4 (LeakyReLU)      (None, 32, 32, 128)  0           ['conv2d_transpose_1[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 32, 32, 3)    24579       ['leaky_re_lu_4[0][0]']
#
# ==================================================================================================
# Total params: 1,382,327
# Trainable params: 1,382,327
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %%
# #Generator is trained via GAN combined model.
# define the combined generator and discriminator model, for updating the generator
#Discriminator is trained separately so here only generator will be trained by keeping
#the discriminator constant.
def define_gan(g_model, d_model):
	d_model.trainable = False  #Discriminator is trained separately. So set to not trainable.

    ## connect generator and discriminator...
	# first, get noise and label inputs from generator model
	gen_noise, gen_label = g_model.input  #Latent vector size and label size
	# get image output from the generator model
	gen_output = g_model.output  #32x32x3

	# generator image output and corresponding input label are inputs to discriminator
	gan_output = d_model([gen_output, gen_label])
	# define gan model as taking noise and label and outputting a classification
	model = Model([gen_noise, gen_label], gan_output)
	# compile model
	opt = Adam(lr=0.0002, beta_1=0.5)
	model.compile(loss='binary_crossentropy', optimizer=opt)
	return model

# %%
# load cifar images
def load_real_samples():
	# load dataset
	(trainX, trainy), (_, _) = load_data()   #cifar
	# convert to floats and scale
	X = trainX.astype('float32')
	# scale from [0,255] to [-1,1]
	X = (X - 127.5) / 127.5   #Generator uses tanh activation so rescale
                            #original images to -1 to 1 to match the output of generator.
	return [X, trainy]

# %%
# # select real samples
# pick a batch of random real samples to train the GAN
#In fact, we will train the GAN on a half batch of real images and another
#half batch of fake images.
#For each real image we assign a label 1 and for fake we assign label 0.
def generate_real_samples(dataset, n_samples):
	# split into images and labels
	images, labels = dataset
	# choose random instances
	ix = randint(0, images.shape[0], n_samples)
	# select images and labels
	X, labels = images[ix], labels[ix]
	# generate class labels and assign to y (don't confuse this with the above labels that correspond to cifar labels)
	y = ones((n_samples, 1))  #Label=1 indicating they are real
	return [X, labels], y

# %%
# generate points in latent space as input for the generator
def generate_latent_points(latent_dim, n_samples, n_classes=10):
	# generate points in the latent space
	x_input = randn(latent_dim * n_samples)
	# reshape into a batch of inputs for the network
	z_input = x_input.reshape(n_samples, latent_dim)
	# generate labels
	labels = randint(0, n_classes, n_samples)
	return [z_input, labels]

# %%
# use the generator to generate n fake examples, with class labels
#Supply the generator, latent_dim and number of samples as input.
#Use the above latent point generator to generate latent points.
def generate_fake_samples(generator, latent_dim, n_samples):
	# generate points in latent space
	z_input, labels_input = generate_latent_points(latent_dim, n_samples)
	# predict outputs
	images = generator.predict([z_input, labels_input])
	# create class labels
	y = zeros((n_samples, 1))  #Label=0 indicating they are fake
	return [images, labels_input], y

# %%
# train the generator and discriminator
#We loop through a number of epochs to train our Discriminator by first selecting
#a random batch of images from our true/real dataset.
#Then, generating a set of images using the generator.
#Feed both set of images into the Discriminator.
#Finally, set the loss parameters for both the real and fake images, as well as the combined loss.
def train(g_model, d_model, gan_model, dataset, latent_dim, n_epochs=100, n_batch=128):
	bat_per_epo = int(dataset[0].shape[0] / n_batch)
	half_batch = int(n_batch / 2)  #the discriminator model is updated for a half batch of real samples
                            #and a half batch of fake samples, combined a single batch.
	# manually enumerate epochs
	for i in range(n_epochs):
		# enumerate batches over the training set
		for j in range(bat_per_epo):

             # Train the discriminator on real and fake images, separately (half batch each)
        #Research showed that separate training is more effective.
			# get randomly selected 'real' samples
            # get randomly selected 'real' samples
			[X_real, labels_real], y_real = generate_real_samples(dataset, half_batch)

            # update discriminator model weights
            ##train_on_batch allows you to update weights based on a collection
            #of samples you provide
			d_loss_real, _ = d_model.train_on_batch([X_real, labels_real], y_real)

			# generate 'fake' examples
			[X_fake, labels], y_fake = generate_fake_samples(g_model, latent_dim, half_batch)
			# update discriminator model weights
			d_loss_fake, _ = d_model.train_on_batch([X_fake, labels], y_fake)

            #d_loss = 0.5 * np.add(d_loss_real, d_loss_fake) #Average loss if you want to report single..

			# prepare points in latent space as input for the generator
			[z_input, labels_input] = generate_latent_points(latent_dim, n_batch)

            # The generator wants the discriminator to label the generated samples
        # as valid (ones)
        #This is where the generator is trying to trick discriminator into believing
        #the generated image is true (hence value of 1 for y)
			# create inverted labels for the fake samples
			y_gan = ones((n_batch, 1))
             # Generator is part of combined model where it got directly linked with the discriminator
        # Train the generator with latent_dim as x and 1 as y.
        # Again, 1 as the output as it is adversarial and if generator did a great
        #job of folling the discriminator then the output would be 1 (true)
			# update the generator via the discriminator's error
			g_loss = gan_model.train_on_batch([z_input, labels_input], y_gan)
			# Print losses on this batch
			print('Epoch>%d, Batch%d/%d, d1=%.3f, d2=%.3f g=%.3f' %
				(i+1, j+1, bat_per_epo, d_loss_real, d_loss_fake, g_loss))
	# save the generator model
	g_model.save('cifar_conditional_generator_25epochs.h5')

# %%
#Train the GAN

# size of the latent space
latent_dim = 100
# create the discriminator
d_model = define_discriminator()
# create the generator
g_model = define_generator(latent_dim)
# create the gan
gan_model = define_gan(g_model, d_model)
# load image data
dataset = load_real_samples()
# train model
train(g_model, d_model, gan_model, dataset, latent_dim, n_epochs=90)

##########################################################
# Out:
# Streaming output truncated to the last 5000 lines.
# 2/2 [==============================] - 0s 6ms/step
# Epoch>84, Batch231/390, d1=0.707, d2=0.688 g=0.712
# 2/2 [==============================] - 0s 7ms/step
# Epoch>84, Batch232/390, d1=0.700, d2=0.688 g=0.720
# 2/2 [==============================] - 0s 11ms/step
# Epoch>84, Batch233/390, d1=0.695, d2=0.699 g=0.710
# 2/2 [==============================] - 0s 4ms/step
# Epoch>84, Batch234/390, d1=0.709, d2=0.713 g=0.700
# 2/2 [==============================] - 0s 5ms/step
# Epoch>84, Batch235/390, d1=0.678, d2=0.720 g=0.696
# 2/2 [==============================] - 0s 7ms/step
# Epoch>84, Batch236/390, d1=0.696, d2=0.704 g=0.706
# 2/2 [==============================] - 0s 6ms/step
# Epoch>84, Batch237/390, d1=0.696, d2=0.704 g=0.694
# 2/2 [==============================] - 0s 6ms/step
# Epoch>84, Batch238/390, d1=0.673, d2=0.703 g=0.697
# 2/2 [==============================] - 0s 9ms/step
# Epoch>84, Batch239/390, d1=0.674, d2=0.698 g=0.686
# 2/2 [==============================] - 0s 6ms/step
# Epoch>84, Batch240/390, d1=0.677, d2=0.707 g=0.698
# 2/2 [==============================] - 0s 10ms/step
# Epoch>84, Batch241/390, d1=0.671, d2=0.710 g=0.696
# 2/2 [==============================] - 0s 8ms/step
# Epoch>84, Batch242/390, d1=0.669, d2=0.705 g=0.701
# 2/2 [==============================] - 0s 13ms/step
# Epoch>84, Batch243/390, d1=0.688, d2=0.689 g=0.710
# 2/2 [==============================] - 0s 13ms/step
# Epoch>84, Batch244/390, d1=0.673, d2=0.681 g=0.716
# 2/2 [==============================] - 0s 9ms/step
# Epoch>84, Batch245/390, d1=0.685, d2=0.689 g=0.730
# 2/2 [==============================] - 0s 11ms/step
# Epoch>84, Batch246/390, d1=0.694, d2=0.673 g=0.719
# 2/2 [==============================] - 0s 5ms/step
# Epoch>84, Batch247/390, d1=0.699, d2=0.673 g=0.730
# 2/2 [==============================] - 0s 6ms/step
# Epoch>84, Batch248/390, d1=0.682, d2=0.690 g=0.716
# 2/2 [==============================] - 0s 5ms/step
# Epoch>84, Batch249/390, d1=0.695, d2=0.684 g=0.726
# 2/2 [==============================] - 0s 6ms/step
# Epoch>84, Batch250/390, d1=0.682, d2=0.684 g=0.728
# 2/2 [==============================] - 0s 14ms/step
# Epoch>84, Batch251/390, d1=0.707, d2=0.700 g=0.724
# 2/2 [==============================] - 0s 8ms/step
# Epoch>84, Batch252/390, d1=0.700, d2=0.693 g=0.716
# 2/2 [==============================] - 0s 12ms/step
# Epoch>84, Batch253/390, d1=0.686, d2=0.695 g=0.702
# 2/2 [==============================] - 0s 8ms/step
# Epoch>84, Batch254/390, d1=0.700, d2=0.705 g=0.703
# 2/2 [==============================] - 0s 6ms/step
# Epoch>84, Batch255/390, d1=0.694, d2=0.695 g=0.706
# 2/2 [==============================] - 0s 5ms/step
# Epoch>84, Batch256/390, d1=0.691, d2=0.693 g=0.700
# 2/2 [==============================] - 0s 6ms/step
# Epoch>84, Batch257/390, d1=0.710, d2=0.688 g=0.717
# 2/2 [==============================] - 0s 12ms/step
# Epoch>84, Batch258/390, d1=0.692, d2=0.693 g=0.725
# 2/2 [==============================] - 0s 5ms/step
# Epoch>84, Batch259/390, d1=0.708, d2=0.692 g=0.733
# 2/2 [==============================] - 0s 5ms/step
# Epoch>84, Batch260/390, d1=0.701, d2=0.685 g=0.729
# 2/2 [==============================] - 0s 11ms/step
# Epoch>84, Batch261/390, d1=0.699, d2=0.677 g=0.726
# 2/2 [==============================] - 0s 11ms/step
# Epoch>84, Batch262/390, d1=0.712, d2=0.684 g=0.722
# 2/2 [==============================] - 0s 10ms/step
# Epoch>84, Batch263/390, d1=0.688, d2=0.684 g=0.727
# 2/2 [==============================] - 0s 10ms/step
# Epoch>84, Batch264/390, d1=0.704, d2=0.681 g=0.730
# 2/2 [==============================] - 0s 4ms/step
# Epoch>84, Batch265/390, d1=0.710, d2=0.680 g=0.726
# 2/2 [==============================] - 0s 7ms/step
# Epoch>84, Batch266/390, d1=0.707, d2=0.685 g=0.714
# 2/2 [==============================] - 0s 10ms/step
# Epoch>84, Batch267/390, d1=0.699, d2=0.692 g=0.721
# 2/2 [==============================] - 0s 4ms/step
# Epoch>84, Batch268/390, d1=0.708, d2=0.686 g=0.713
# 2/2 [==============================] - 0s 5ms/step
# Epoch>84, Batch269/390, d1=0.698, d2=0.699 g=0.705
# 2/2 [==============================] - 0s 5ms/step
# Epoch>84, Batch270/390, d1=0.701, d2=0.693 g=0.711
# 2/2 [==============================] - 0s 10ms/step
# Epoch>84, Batch271/390, d1=0.689, d2=0.694 g=0.705
# 2/2 [==============================] - 0s 8ms/step
# Epoch>84, Batch272/390, d1=0.706, d2=0.683 g=0.714
# 2/2 [==============================] - 0s 11ms/step
# Epoch>84, Batch273/390, d1=0.700, d2=0.702 g=0.716
# 2/2 [==============================] - 0s 9ms/step
# Epoch>84, Batch274/390, d1=0.687, d2=0.698 g=0.720
# 2/2 [==============================] - 0s 6ms/step
# Epoch>84, Batch275/390, d1=0.697, d2=0.691 g=0.716
# 2/2 [==============================] - 0s 8ms/step
# Epoch>84, Batch276/390, d1=0.699, d2=0.691 g=0.705
# 2/2 [==============================] - 0s 6ms/step
# Epoch>84, Batch277/390, d1=0.693, d2=0.684 g=0.709
# 2/2 [==============================] - 0s 13ms/step
# Epoch>84, Batch278/390, d1=0.695, d2=0.693 g=0.720
# 2/2 [==============================] - 0s 5ms/step
# Epoch>84, Batch279/390, d1=0.696, d2=0.687 g=0.718
# 2/2 [==============================] - 0s 6ms/step
# Epoch>84, Batch280/390, d1=0.681, d2=0.690 g=0.715
# 2/2 [==============================] - 0s 9ms/step
# Epoch>84, Batch281/390, d1=0.694, d2=0.690 g=0.708
# 2/2 [==============================] - 0s 8ms/step
# Epoch>84, Batch282/390, d1=0.698, d2=0.686 g=0.713
# 2/2 [==============================] - 0s 5ms/step
# Epoch>84, Batch283/390, d1=0.680, d2=0.704 g=0.720
# 2/2 [==============================] - 0s 6ms/step
# Epoch>84, Batch284/390, d1=0.710, d2=0.702 g=0.714
# 2/2 [==============================] - 0s 5ms/step
# Epoch>84, Batch285/390, d1=0.708, d2=0.688 g=0.719
# 2/2 [==============================] - 0s 7ms/step
# Epoch>84, Batch286/390, d1=0.691, d2=0.677 g=0.728
# 2/2 [==============================] - 0s 12ms/step
# Epoch>84, Batch287/390, d1=0.704, d2=0.685 g=0.729
# 2/2 [==============================] - 0s 5ms/step
# Epoch>84, Batch288/390, d1=0.701, d2=0.676 g=0.724
# 2/2 [==============================] - 0s 5ms/step
# Epoch>84, Batch289/390, d1=0.694, d2=0.685 g=0.734
# 2/2 [==============================] - 0s 6ms/step
# Epoch>84, Batch290/390, d1=0.699, d2=0.677 g=0.732
# 2/2 [==============================] - 0s 7ms/step
# Epoch>84, Batch291/390, d1=0.706, d2=0.675 g=0.731
# 2/2 [==============================] - 0s 6ms/step
# Epoch>84, Batch292/390, d1=0.693, d2=0.683 g=0.744
# 2/2 [==============================] - 0s 6ms/step
# Epoch>84, Batch293/390, d1=0.707, d2=0.657 g=0.737
# 2/2 [==============================] - 0s 13ms/step
# Epoch>84, Batch294/390, d1=0.709, d2=0.676 g=0.730
# 2/2 [==============================] - 0s 5ms/step
# Epoch>84, Batch295/390, d1=0.696, d2=0.684 g=0.724
# 2/2 [==============================] - 0s 13ms/step
# Epoch>84, Batch296/390, d1=0.702, d2=0.682 g=0.718
# 2/2 [==============================] - 0s 12ms/step
# Epoch>84, Batch297/390, d1=0.682, d2=0.692 g=0.724
# 2/2 [==============================] - 0s 5ms/step
# Epoch>84, Batch298/390, d1=0.697, d2=0.684 g=0.704
# 2/2 [==============================] - 0s 7ms/step
# Epoch>84, Batch299/390, d1=0.697, d2=0.705 g=0.712
# 2/2 [==============================] - 0s 8ms/step
# Epoch>84, Batch300/390, d1=0.700, d2=0.688 g=0.707
# 2/2 [==============================] - 0s 7ms/step
# Epoch>84, Batch301/390, d1=0.691, d2=0.702 g=0.704
# 2/2 [==============================] - 0s 14ms/step
# Epoch>84, Batch302/390, d1=0.694, d2=0.702 g=0.712
# 2/2 [==============================] - 0s 4ms/step
# Epoch>84, Batch303/390, d1=0.676, d2=0.690 g=0.715
# 2/2 [==============================] - 0s 5ms/step
# Epoch>84, Batch304/390, d1=0.700, d2=0.693 g=0.707
# 2/2 [==============================] - 0s 10ms/step
# Epoch>84, Batch305/390, d1=0.681, d2=0.686 g=0.698
# 2/2 [==============================] - 0s 7ms/step
# Epoch>84, Batch306/390, d1=0.687, d2=0.694 g=0.701
# 2/2 [==============================] - 0s 5ms/step
# Epoch>84, Batch307/390, d1=0.682, d2=0.698 g=0.731
# 2/2 [==============================] - 0s 5ms/step
# Epoch>84, Batch308/390, d1=0.685, d2=0.684 g=0.719
# 2/2 [==============================] - 0s 4ms/step
# Epoch>84, Batch309/390, d1=0.694, d2=0.705 g=0.720
# 2/2 [==============================] - 0s 4ms/step
# Epoch>84, Batch310/390, d1=0.678, d2=0.696 g=0.704
# 2/2 [==============================] - 0s 6ms/step
# Epoch>84, Batch311/390, d1=0.703, d2=0.704 g=0.709
# 2/2 [==============================] - 0s 4ms/step
# Epoch>84, Batch312/390, d1=0.691, d2=0.693 g=0.700
# 2/2 [==============================] - 0s 4ms/step
# Epoch>84, Batch313/390, d1=0.690, d2=0.709 g=0.709
# 2/2 [==============================] - 0s 11ms/step
# Epoch>84, Batch314/390, d1=0.698, d2=0.710 g=0.706
# 2/2 [==============================] - 0s 5ms/step
# Epoch>84, Batch315/390, d1=0.675, d2=0.700 g=0.710
# 2/2 [==============================] - 0s 15ms/step
# Epoch>84, Batch316/390, d1=0.688, d2=0.701 g=0.704
# 2/2 [==============================] - 0s 15ms/step
# Epoch>84, Batch317/390, d1=0.681, d2=0.703 g=0.694
# 2/2 [==============================] - 0s 4ms/step
# Epoch>84, Batch318/390, d1=0.702, d2=0.699 g=0.719
# 2/2 [==============================] - 0s 4ms/step
# Epoch>84, Batch319/390, d1=0.694, d2=0.695 g=0.706
# 2/2 [==============================] - 0s 8ms/step
# Epoch>84, Batch320/390, d1=0.705, d2=0.694 g=0.712
# 2/2 [==============================] - 0s 5ms/step
# Epoch>84, Batch321/390, d1=0.700, d2=0.694 g=0.716
# 2/2 [==============================] - 0s 4ms/step
# Epoch>84, Batch322/390, d1=0.692, d2=0.683 g=0.716
# 2/2 [==============================] - 0s 7ms/step
# Epoch>84, Batch323/390, d1=0.698, d2=0.683 g=0.721
# 2/2 [==============================] - 0s 7ms/step
# Epoch>84, Batch324/390, d1=0.698, d2=0.681 g=0.720
# 2/2 [==============================] - 0s 5ms/step
# Epoch>84, Batch325/390, d1=0.702, d2=0.698 g=0.727
# 2/2 [==============================] - 0s 5ms/step
# Epoch>84, Batch326/390, d1=0.697, d2=0.683 g=0.722
# 2/2 [==============================] - 0s 8ms/step
# Epoch>84, Batch327/390, d1=0.704, d2=0.690 g=0.722
# 2/2 [==============================] - 0s 4ms/step
# Epoch>84, Batch328/390, d1=0.708, d2=0.687 g=0.721
# 2/2 [==============================] - 0s 5ms/step
# Epoch>84, Batch329/390, d1=0.696, d2=0.688 g=0.719
# 2/2 [==============================] - 0s 16ms/step
# Epoch>84, Batch330/390, d1=0.699, d2=0.706 g=0.718
# 2/2 [==============================] - 0s 6ms/step
# Epoch>84, Batch331/390, d1=0.724, d2=0.701 g=0.726
# 2/2 [==============================] - 0s 6ms/step
# Epoch>84, Batch332/390, d1=0.710, d2=0.681 g=0.723
# 2/2 [==============================] - 0s 5ms/step
# Epoch>84, Batch333/390, d1=0.697, d2=0.686 g=0.721
# 2/2 [==============================] - 0s 6ms/step
# Epoch>84, Batch334/390, d1=0.684, d2=0.687 g=0.716
# 2/2 [==============================] - 0s 8ms/step
# Epoch>84, Batch335/390, d1=0.711, d2=0.690 g=0.711
# 2/2 [==============================] - 0s 4ms/step
# Epoch>84, Batch336/390, d1=0.678, d2=0.689 g=0.714
# 2/2 [==============================] - 0s 4ms/step
# Epoch>84, Batch337/390, d1=0.706, d2=0.700 g=0.709
# 2/2 [==============================] - 0s 10ms/step
# Epoch>84, Batch338/390, d1=0.686, d2=0.705 g=0.705
# 2/2 [==============================] - 0s 7ms/step
# Epoch>84, Batch339/390, d1=0.694, d2=0.685 g=0.716
# 2/2 [==============================] - 0s 9ms/step
# Epoch>84, Batch340/390, d1=0.701, d2=0.694 g=0.719
# 2/2 [==============================] - 0s 11ms/step
# Epoch>84, Batch341/390, d1=0.694, d2=0.684 g=0.730
# 2/2 [==============================] - 0s 10ms/step
# Epoch>84, Batch342/390, d1=0.688, d2=0.699 g=0.713
# 2/2 [==============================] - 0s 4ms/step
# Epoch>84, Batch343/390, d1=0.685, d2=0.685 g=0.709
# 2/2 [==============================] - 0s 12ms/step
# Epoch>84, Batch344/390, d1=0.667, d2=0.683 g=0.704
# 2/2 [==============================] - 0s 5ms/step
# Epoch>84, Batch345/390, d1=0.699, d2=0.678 g=0.711
# 2/2 [==============================] - 0s 7ms/step
# Epoch>84, Batch346/390, d1=0.693, d2=0.692 g=0.722
# 2/2 [==============================] - 0s 6ms/step
# Epoch>84, Batch347/390, d1=0.679, d2=0.682 g=0.718
# 2/2 [==============================] - 0s 6ms/step
# Epoch>84, Batch348/390, d1=0.709, d2=0.674 g=0.739
# 2/2 [==============================] - 0s 7ms/step
# Epoch>84, Batch349/390, d1=0.676, d2=0.667 g=0.735
# 2/2 [==============================] - 0s 6ms/step
# Epoch>84, Batch350/390, d1=0.682, d2=0.662 g=0.726
# 2/2 [==============================] - 0s 5ms/step
# Epoch>84, Batch351/390, d1=0.678, d2=0.707 g=0.701
# 2/2 [==============================] - 0s 5ms/step
# Epoch>84, Batch352/390, d1=0.717, d2=0.713 g=0.711
# 2/2 [==============================] - 0s 6ms/step
# Epoch>84, Batch353/390, d1=0.686, d2=0.715 g=0.710
# 2/2 [==============================] - 0s 5ms/step
# Epoch>84, Batch354/390, d1=0.682, d2=0.713 g=0.717
# 2/2 [==============================] - 0s 6ms/step
# Epoch>84, Batch355/390, d1=0.697, d2=0.681 g=0.727
# 2/2 [==============================] - 0s 9ms/step
# Epoch>84, Batch356/390, d1=0.708, d2=0.655 g=0.745
# 2/2 [==============================] - 0s 5ms/step
# Epoch>84, Batch357/390, d1=0.700, d2=0.643 g=0.734
# 2/2 [==============================] - 0s 5ms/step
# Epoch>84, Batch358/390, d1=0.666, d2=0.677 g=0.752
# 2/2 [==============================] - 0s 15ms/step
# Epoch>84, Batch359/390, d1=0.710, d2=0.702 g=0.715
# 2/2 [==============================] - 0s 12ms/step
# Epoch>84, Batch360/390, d1=0.677, d2=0.717 g=0.703
# 2/2 [==============================] - 0s 5ms/step
# Epoch>84, Batch361/390, d1=0.703, d2=0.724 g=0.695
# 2/2 [==============================] - 0s 5ms/step
# Epoch>84, Batch362/390, d1=0.702, d2=0.725 g=0.721
# 2/2 [==============================] - 0s 13ms/step
# Epoch>84, Batch363/390, d1=0.694, d2=0.683 g=0.746
# 2/2 [==============================] - 0s 10ms/step
# Epoch>84, Batch364/390, d1=0.690, d2=0.670 g=0.761
# 2/2 [==============================] - 0s 9ms/step
# Epoch>84, Batch365/390, d1=0.700, d2=0.653 g=0.752
# 2/2 [==============================] - 0s 13ms/step
# Epoch>84, Batch366/390, d1=0.697, d2=0.682 g=0.734
# 2/2 [==============================] - 0s 4ms/step
# Epoch>84, Batch367/390, d1=0.685, d2=0.682 g=0.699
# 2/2 [==============================] - 0s 6ms/step
# Epoch>84, Batch368/390, d1=0.698, d2=0.709 g=0.719
# 2/2 [==============================] - 0s 12ms/step
# Epoch>84, Batch369/390, d1=0.693, d2=0.726 g=0.706
# 2/2 [==============================] - 0s 8ms/step
# Epoch>84, Batch370/390, d1=0.691, d2=0.698 g=0.701
# 2/2 [==============================] - 0s 5ms/step
# Epoch>84, Batch371/390, d1=0.707, d2=0.692 g=0.704
# 2/2 [==============================] - 0s 10ms/step
# Epoch>84, Batch372/390, d1=0.703, d2=0.678 g=0.735
# 2/2 [==============================] - 0s 5ms/step
# Epoch>84, Batch373/390, d1=0.687, d2=0.664 g=0.754
# 2/2 [==============================] - 0s 9ms/step
# Epoch>84, Batch374/390, d1=0.678, d2=0.680 g=0.733
# 2/2 [==============================] - 0s 9ms/step
# Epoch>84, Batch375/390, d1=0.675, d2=0.680 g=0.703
# 2/2 [==============================] - 0s 5ms/step
# Epoch>84, Batch376/390, d1=0.695, d2=0.718 g=0.709
# 2/2 [==============================] - 0s 4ms/step
# Epoch>84, Batch377/390, d1=0.706, d2=0.732 g=0.710
# 2/2 [==============================] - 0s 10ms/step
# Epoch>84, Batch378/390, d1=0.699, d2=0.715 g=0.709
# 2/2 [==============================] - 0s 6ms/step
# Epoch>84, Batch379/390, d1=0.680, d2=0.698 g=0.717
# 2/2 [==============================] - 0s 8ms/step
# Epoch>84, Batch380/390, d1=0.700, d2=0.677 g=0.752
# 2/2 [==============================] - 0s 7ms/step
# Epoch>84, Batch381/390, d1=0.687, d2=0.645 g=0.767
# 2/2 [==============================] - 0s 5ms/step
# Epoch>84, Batch382/390, d1=0.674, d2=0.663 g=0.778
# 2/2 [==============================] - 0s 11ms/step
# Epoch>84, Batch383/390, d1=0.697, d2=0.645 g=0.756
# 2/2 [==============================] - 0s 5ms/step
# Epoch>84, Batch384/390, d1=0.682, d2=0.692 g=0.727
# 2/2 [==============================] - 0s 13ms/step
# Epoch>84, Batch385/390, d1=0.673, d2=0.728 g=0.682
# 2/2 [==============================] - 0s 4ms/step
# Epoch>84, Batch386/390, d1=0.676, d2=0.761 g=0.673
# 2/2 [==============================] - 0s 4ms/step
# Epoch>84, Batch387/390, d1=0.698, d2=0.745 g=0.713
# 2/2 [==============================] - 0s 8ms/step
# Epoch>84, Batch388/390, d1=0.701, d2=0.681 g=0.753
# 2/2 [==============================] - 0s 7ms/step
# Epoch>84, Batch389/390, d1=0.691, d2=0.654 g=0.763
# 2/2 [==============================] - 0s 7ms/step
# Epoch>84, Batch390/390, d1=0.678, d2=0.678 g=0.729
# 2/2 [==============================] - 0s 6ms/step
# Epoch>85, Batch1/390, d1=0.675, d2=0.695 g=0.711
# 2/2 [==============================] - 0s 8ms/step
# Epoch>85, Batch2/390, d1=0.676, d2=0.725 g=0.689
# 2/2 [==============================] - 0s 4ms/step
# Epoch>85, Batch3/390, d1=0.704, d2=0.752 g=0.681
# 2/2 [==============================] - 0s 5ms/step
# Epoch>85, Batch4/390, d1=0.711, d2=0.720 g=0.694
# 2/2 [==============================] - 0s 11ms/step
# Epoch>85, Batch5/390, d1=0.695, d2=0.715 g=0.711
# 2/2 [==============================] - 0s 4ms/step
# Epoch>85, Batch6/390, d1=0.695, d2=0.691 g=0.744
# 2/2 [==============================] - 0s 11ms/step
# Epoch>85, Batch7/390, d1=0.698, d2=0.669 g=0.749
# 2/2 [==============================] - 0s 9ms/step
# Epoch>85, Batch8/390, d1=0.693, d2=0.655 g=0.765
# 2/2 [==============================] - 0s 12ms/step
# Epoch>85, Batch9/390, d1=0.684, d2=0.663 g=0.754
# 2/2 [==============================] - 0s 11ms/step
# Epoch>85, Batch10/390, d1=0.682, d2=0.673 g=0.731
# 2/2 [==============================] - 0s 5ms/step
# Epoch>85, Batch11/390, d1=0.701, d2=0.707 g=0.698
# 2/2 [==============================] - 0s 5ms/step
# Epoch>85, Batch12/390, d1=0.711, d2=0.725 g=0.695
# 2/2 [==============================] - 0s 5ms/step
# Epoch>85, Batch13/390, d1=0.691, d2=0.734 g=0.708
# 2/2 [==============================] - 0s 4ms/step
# Epoch>85, Batch14/390, d1=0.699, d2=0.691 g=0.730
# 2/2 [==============================] - 0s 11ms/step
# Epoch>85, Batch15/390, d1=0.687, d2=0.674 g=0.741
# 2/2 [==============================] - 0s 12ms/step
# Epoch>85, Batch16/390, d1=0.696, d2=0.693 g=0.719
# 2/2 [==============================] - 0s 9ms/step
# Epoch>85, Batch17/390, d1=0.690, d2=0.705 g=0.701
# 2/2 [==============================] - 0s 5ms/step
# Epoch>85, Batch18/390, d1=0.696, d2=0.716 g=0.705
# 2/2 [==============================] - 0s 12ms/step
# Epoch>85, Batch19/390, d1=0.692, d2=0.699 g=0.686
# 2/2 [==============================] - 0s 4ms/step
# Epoch>85, Batch20/390, d1=0.678, d2=0.713 g=0.701
# 2/2 [==============================] - 0s 5ms/step
# Epoch>85, Batch21/390, d1=0.691, d2=0.695 g=0.703
# 2/2 [==============================] - 0s 10ms/step
# Epoch>85, Batch22/390, d1=0.689, d2=0.702 g=0.723
# 2/2 [==============================] - 0s 7ms/step
# Epoch>85, Batch23/390, d1=0.697, d2=0.693 g=0.715
# 2/2 [==============================] - 0s 9ms/step
# Epoch>85, Batch24/390, d1=0.691, d2=0.694 g=0.712
# 2/2 [==============================] - 0s 9ms/step
# Epoch>85, Batch25/390, d1=0.674, d2=0.720 g=0.709
# 2/2 [==============================] - 0s 9ms/step
# Epoch>85, Batch26/390, d1=0.692, d2=0.715 g=0.712
# 2/2 [==============================] - 0s 4ms/step
# Epoch>85, Batch27/390, d1=0.701, d2=0.704 g=0.699
# 2/2 [==============================] - 0s 6ms/step
# Epoch>85, Batch28/390, d1=0.686, d2=0.685 g=0.703
# 2/2 [==============================] - 0s 4ms/step
# Epoch>85, Batch29/390, d1=0.689, d2=0.691 g=0.708
# 2/2 [==============================] - 0s 7ms/step
# Epoch>85, Batch30/390, d1=0.697, d2=0.698 g=0.713
# 2/2 [==============================] - 0s 5ms/step
# Epoch>85, Batch31/390, d1=0.691, d2=0.706 g=0.716
# 2/2 [==============================] - 0s 6ms/step
# Epoch>85, Batch32/390, d1=0.685, d2=0.690 g=0.704
# 2/2 [==============================] - 0s 11ms/step
# Epoch>85, Batch33/390, d1=0.688, d2=0.710 g=0.708
# 2/2 [==============================] - 0s 8ms/step
# Epoch>85, Batch34/390, d1=0.703, d2=0.688 g=0.716
# 2/2 [==============================] - 0s 11ms/step
# Epoch>85, Batch35/390, d1=0.708, d2=0.692 g=0.712
# 2/2 [==============================] - 0s 9ms/step
# Epoch>85, Batch36/390, d1=0.696, d2=0.673 g=0.716
# 2/2 [==============================] - 0s 8ms/step
# Epoch>85, Batch37/390, d1=0.709, d2=0.703 g=0.712
# 2/2 [==============================] - 0s 18ms/step
# Epoch>85, Batch38/390, d1=0.701, d2=0.697 g=0.710
# 2/2 [==============================] - 0s 6ms/step
# Epoch>85, Batch39/390, d1=0.688, d2=0.687 g=0.705
# 2/2 [==============================] - 0s 6ms/step
# Epoch>85, Batch40/390, d1=0.706, d2=0.704 g=0.705
# 2/2 [==============================] - 0s 5ms/step
# Epoch>85, Batch41/390, d1=0.702, d2=0.711 g=0.702
# 2/2 [==============================] - 0s 6ms/step
# Epoch>85, Batch42/390, d1=0.689, d2=0.686 g=0.714
# 2/2 [==============================] - 0s 4ms/step
# Epoch>85, Batch43/390, d1=0.699, d2=0.692 g=0.705
# 2/2 [==============================] - 0s 5ms/step
# Epoch>85, Batch44/390, d1=0.704, d2=0.694 g=0.716
# 2/2 [==============================] - 0s 17ms/step
# Epoch>85, Batch45/390, d1=0.693, d2=0.693 g=0.724
# 2/2 [==============================] - 0s 15ms/step
# Epoch>85, Batch46/390, d1=0.718, d2=0.688 g=0.714
# 2/2 [==============================] - 0s 11ms/step
# Epoch>85, Batch47/390, d1=0.708, d2=0.697 g=0.714
# 2/2 [==============================] - 0s 5ms/step
# Epoch>85, Batch48/390, d1=0.695, d2=0.678 g=0.709
# 2/2 [==============================] - 0s 8ms/step
# Epoch>85, Batch49/390, d1=0.709, d2=0.693 g=0.709
# 2/2 [==============================] - 0s 17ms/step
# Epoch>85, Batch50/390, d1=0.703, d2=0.679 g=0.719
# 2/2 [==============================] - 0s 9ms/step
# Epoch>85, Batch51/390, d1=0.702, d2=0.676 g=0.707
# 2/2 [==============================] - 0s 5ms/step
# Epoch>85, Batch52/390, d1=0.704, d2=0.691 g=0.718
# 2/2 [==============================] - 0s 5ms/step
# Epoch>85, Batch53/390, d1=0.705, d2=0.688 g=0.718
# 2/2 [==============================] - 0s 16ms/step
# Epoch>85, Batch54/390, d1=0.711, d2=0.668 g=0.714
# 2/2 [==============================] - 0s 17ms/step
# Epoch>85, Batch55/390, d1=0.709, d2=0.687 g=0.712
# 2/2 [==============================] - 0s 6ms/step
# Epoch>85, Batch56/390, d1=0.706, d2=0.704 g=0.706
# 2/2 [==============================] - 0s 12ms/step
# Epoch>85, Batch57/390, d1=0.684, d2=0.708 g=0.707
# 2/2 [==============================] - 0s 13ms/step
# Epoch>85, Batch58/390, d1=0.695, d2=0.696 g=0.705
# 2/2 [==============================] - 0s 6ms/step
# Epoch>85, Batch59/390, d1=0.693, d2=0.706 g=0.707
# 2/2 [==============================] - 0s 12ms/step
# Epoch>85, Batch60/390, d1=0.706, d2=0.695 g=0.714
# 2/2 [==============================] - 0s 6ms/step
# Epoch>85, Batch61/390, d1=0.694, d2=0.695 g=0.698
# 2/2 [==============================] - 0s 5ms/step
# Epoch>85, Batch62/390, d1=0.698, d2=0.696 g=0.703
# 2/2 [==============================] - 0s 7ms/step
# Epoch>85, Batch63/390, d1=0.687, d2=0.696 g=0.718
# 2/2 [==============================] - 0s 12ms/step
# Epoch>85, Batch64/390, d1=0.703, d2=0.686 g=0.714
# 2/2 [==============================] - 0s 5ms/step
# Epoch>85, Batch65/390, d1=0.692, d2=0.707 g=0.710
# 2/2 [==============================] - 0s 12ms/step
# Epoch>85, Batch66/390, d1=0.701, d2=0.701 g=0.711
# 2/2 [==============================] - 0s 11ms/step
# Epoch>85, Batch67/390, d1=0.687, d2=0.677 g=0.719
# 2/2 [==============================] - 0s 8ms/step
# Epoch>85, Batch68/390, d1=0.697, d2=0.685 g=0.722
# 2/2 [==============================] - 0s 6ms/step
# Epoch>85, Batch69/390, d1=0.700, d2=0.672 g=0.719
# 2/2 [==============================] - 0s 5ms/step
# Epoch>85, Batch70/390, d1=0.697, d2=0.698 g=0.734
# 2/2 [==============================] - 0s 5ms/step
# Epoch>85, Batch71/390, d1=0.693, d2=0.674 g=0.718
# 2/2 [==============================] - 0s 17ms/step
# Epoch>85, Batch72/390, d1=0.723, d2=0.691 g=0.719
# 2/2 [==============================] - 0s 10ms/step
# Epoch>85, Batch73/390, d1=0.715, d2=0.677 g=0.724
# 2/2 [==============================] - 0s 14ms/step
# Epoch>85, Batch74/390, d1=0.696, d2=0.680 g=0.720
# 2/2 [==============================] - 0s 7ms/step
# Epoch>85, Batch75/390, d1=0.703, d2=0.671 g=0.725
# 2/2 [==============================] - 0s 11ms/step
# Epoch>85, Batch76/390, d1=0.719, d2=0.677 g=0.720
# 2/2 [==============================] - 0s 14ms/step
# Epoch>85, Batch77/390, d1=0.697, d2=0.678 g=0.712
# 2/2 [==============================] - 0s 11ms/step
# Epoch>85, Batch78/390, d1=0.720, d2=0.688 g=0.707
# 2/2 [==============================] - 0s 5ms/step
# Epoch>85, Batch79/390, d1=0.703, d2=0.681 g=0.708
# 2/2 [==============================] - 0s 8ms/step
# Epoch>85, Batch80/390, d1=0.716, d2=0.701 g=0.698
# 2/2 [==============================] - 0s 8ms/step
# Epoch>85, Batch81/390, d1=0.718, d2=0.692 g=0.703
# 2/2 [==============================] - 0s 4ms/step
# Epoch>85, Batch82/390, d1=0.703, d2=0.687 g=0.697
# 2/2 [==============================] - 0s 10ms/step
# Epoch>85, Batch83/390, d1=0.709, d2=0.705 g=0.705
# 2/2 [==============================] - 0s 4ms/step
# Epoch>85, Batch84/390, d1=0.692, d2=0.700 g=0.707
# 2/2 [==============================] - 0s 4ms/step
# Epoch>85, Batch85/390, d1=0.700, d2=0.704 g=0.704
# 2/2 [==============================] - 0s 4ms/step
# Epoch>85, Batch86/390, d1=0.692, d2=0.701 g=0.711
# 2/2 [==============================] - 0s 7ms/step
# Epoch>85, Batch87/390, d1=0.691, d2=0.684 g=0.712
# 2/2 [==============================] - 0s 8ms/step
# Epoch>85, Batch88/390, d1=0.698, d2=0.695 g=0.704
# 2/2 [==============================] - 0s 6ms/step
# Epoch>85, Batch89/390, d1=0.711, d2=0.693 g=0.698
# 2/2 [==============================] - 0s 5ms/step
# Epoch>85, Batch90/390, d1=0.688, d2=0.696 g=0.710
# 2/2 [==============================] - 0s 6ms/step
# Epoch>85, Batch91/390, d1=0.690, d2=0.698 g=0.711
# 2/2 [==============================] - 0s 11ms/step
# Epoch>85, Batch92/390, d1=0.681, d2=0.698 g=0.727
# 2/2 [==============================] - 0s 5ms/step
# Epoch>85, Batch93/390, d1=0.702, d2=0.693 g=0.715
# 2/2 [==============================] - 0s 5ms/step
# Epoch>85, Batch94/390, d1=0.691, d2=0.681 g=0.718
# 2/2 [==============================] - 0s 7ms/step
# Epoch>85, Batch95/390, d1=0.696, d2=0.685 g=0.704
# 2/2 [==============================] - 0s 12ms/step
# Epoch>85, Batch96/390, d1=0.691, d2=0.702 g=0.708
# 2/2 [==============================] - 0s 12ms/step
# Epoch>85, Batch97/390, d1=0.694, d2=0.694 g=0.705
# 2/2 [==============================] - 0s 7ms/step
# Epoch>85, Batch98/390, d1=0.703, d2=0.683 g=0.708
# 2/2 [==============================] - 0s 6ms/step
# Epoch>85, Batch99/390, d1=0.698, d2=0.687 g=0.715
# 2/2 [==============================] - 0s 8ms/step
# Epoch>85, Batch100/390, d1=0.702, d2=0.700 g=0.720
# 2/2 [==============================] - 0s 4ms/step
# Epoch>85, Batch101/390, d1=0.708, d2=0.677 g=0.723
# 2/2 [==============================] - 0s 6ms/step
# Epoch>85, Batch102/390, d1=0.708, d2=0.675 g=0.715
# 2/2 [==============================] - 0s 7ms/step
# Epoch>85, Batch103/390, d1=0.705, d2=0.680 g=0.716
# 2/2 [==============================] - 0s 9ms/step
# Epoch>85, Batch104/390, d1=0.702, d2=0.687 g=0.720
# 2/2 [==============================] - 0s 10ms/step
# Epoch>85, Batch105/390, d1=0.702, d2=0.687 g=0.705
# 2/2 [==============================] - 0s 6ms/step
# Epoch>85, Batch106/390, d1=0.714, d2=0.666 g=0.714
# 2/2 [==============================] - 0s 7ms/step
# Epoch>85, Batch107/390, d1=0.701, d2=0.675 g=0.716
# 2/2 [==============================] - 0s 7ms/step
# Epoch>85, Batch108/390, d1=0.708, d2=0.686 g=0.718
# 2/2 [==============================] - 0s 6ms/step
# Epoch>85, Batch109/390, d1=0.706, d2=0.674 g=0.722
# 2/2 [==============================] - 0s 14ms/step
# Epoch>85, Batch110/390, d1=0.709, d2=0.691 g=0.709
# 2/2 [==============================] - 0s 11ms/step
# Epoch>85, Batch111/390, d1=0.709, d2=0.705 g=0.705
# 2/2 [==============================] - 0s 7ms/step
# Epoch>85, Batch112/390, d1=0.701, d2=0.708 g=0.720
# 2/2 [==============================] - 0s 6ms/step
# Epoch>85, Batch113/390, d1=0.707, d2=0.700 g=0.709
# 2/2 [==============================] - 0s 10ms/step
# Epoch>85, Batch114/390, d1=0.714, d2=0.696 g=0.703
# 2/2 [==============================] - 0s 7ms/step
# Epoch>85, Batch115/390, d1=0.704, d2=0.690 g=0.713
# 2/2 [==============================] - 0s 8ms/step
# Epoch>85, Batch116/390, d1=0.689, d2=0.699 g=0.705
# 2/2 [==============================] - 0s 7ms/step
# Epoch>85, Batch117/390, d1=0.694, d2=0.685 g=0.713
# 2/2 [==============================] - 0s 6ms/step
# Epoch>85, Batch118/390, d1=0.695, d2=0.683 g=0.710
# 2/2 [==============================] - 0s 6ms/step
# Epoch>85, Batch119/390, d1=0.678, d2=0.684 g=0.699
# 2/2 [==============================] - 0s 11ms/step
# Epoch>85, Batch120/390, d1=0.705, d2=0.674 g=0.711
# 2/2 [==============================] - 0s 10ms/step
# Epoch>85, Batch121/390, d1=0.687, d2=0.694 g=0.716
# 2/2 [==============================] - 0s 12ms/step
# Epoch>85, Batch122/390, d1=0.700, d2=0.688 g=0.719
# 2/2 [==============================] - 0s 7ms/step
# Epoch>85, Batch123/390, d1=0.699, d2=0.674 g=0.714
# 2/2 [==============================] - 0s 6ms/step
# Epoch>85, Batch124/390, d1=0.700, d2=0.686 g=0.710
# 2/2 [==============================] - 0s 4ms/step
# Epoch>85, Batch125/390, d1=0.698, d2=0.700 g=0.708
# 2/2 [==============================] - 0s 5ms/step
# Epoch>85, Batch126/390, d1=0.694, d2=0.702 g=0.705
# 2/2 [==============================] - 0s 5ms/step
# Epoch>85, Batch127/390, d1=0.675, d2=0.717 g=0.698
# 2/2 [==============================] - 0s 19ms/step
# Epoch>85, Batch128/390, d1=0.690, d2=0.709 g=0.699
# 2/2 [==============================] - 0s 4ms/step
# Epoch>85, Batch129/390, d1=0.690, d2=0.701 g=0.697
# 2/2 [==============================] - 0s 9ms/step
# Epoch>85, Batch130/390, d1=0.696, d2=0.709 g=0.696
# 2/2 [==============================] - 0s 6ms/step
# Epoch>85, Batch131/390, d1=0.688, d2=0.704 g=0.701
# 2/2 [==============================] - 0s 14ms/step
# Epoch>85, Batch132/390, d1=0.690, d2=0.710 g=0.698
# 2/2 [==============================] - 0s 6ms/step
# Epoch>85, Batch133/390, d1=0.686, d2=0.705 g=0.710
# 2/2 [==============================] - 0s 7ms/step
# Epoch>85, Batch134/390, d1=0.700, d2=0.701 g=0.705
# 2/2 [==============================] - 0s 8ms/step
# Epoch>85, Batch135/390, d1=0.692, d2=0.693 g=0.715
# 2/2 [==============================] - 0s 8ms/step
# Epoch>85, Batch136/390, d1=0.683, d2=0.692 g=0.724
# 2/2 [==============================] - 0s 6ms/step
# Epoch>85, Batch137/390, d1=0.699, d2=0.680 g=0.727
# 2/2 [==============================] - 0s 14ms/step
# Epoch>85, Batch138/390, d1=0.703, d2=0.671 g=0.715
# 2/2 [==============================] - 0s 6ms/step
# Epoch>85, Batch139/390, d1=0.697, d2=0.673 g=0.728
# 2/2 [==============================] - 0s 5ms/step
# Epoch>85, Batch140/390, d1=0.705, d2=0.674 g=0.726
# 2/2 [==============================] - 0s 14ms/step
# Epoch>85, Batch141/390, d1=0.707, d2=0.671 g=0.726
# 2/2 [==============================] - 0s 5ms/step
# Epoch>85, Batch142/390, d1=0.684, d2=0.661 g=0.727
# 2/2 [==============================] - 0s 5ms/step
# Epoch>85, Batch143/390, d1=0.697, d2=0.679 g=0.727
# 2/2 [==============================] - 0s 5ms/step
# Epoch>85, Batch144/390, d1=0.689, d2=0.676 g=0.713
# 2/2 [==============================] - 0s 16ms/step
# Epoch>85, Batch145/390, d1=0.694, d2=0.675 g=0.713
# 2/2 [==============================] - 0s 11ms/step
# Epoch>85, Batch146/390, d1=0.701, d2=0.692 g=0.710
# 2/2 [==============================] - 0s 6ms/step
# Epoch>85, Batch147/390, d1=0.701, d2=0.713 g=0.711
# 2/2 [==============================] - 0s 4ms/step
# Epoch>85, Batch148/390, d1=0.687, d2=0.702 g=0.706
# 2/2 [==============================] - 0s 6ms/step
# Epoch>85, Batch149/390, d1=0.686, d2=0.693 g=0.703
# 2/2 [==============================] - 0s 4ms/step
# Epoch>85, Batch150/390, d1=0.689, d2=0.697 g=0.710
# 2/2 [==============================] - 0s 12ms/step
# Epoch>85, Batch151/390, d1=0.705, d2=0.706 g=0.706
# 2/2 [==============================] - 0s 10ms/step
# Epoch>85, Batch152/390, d1=0.689, d2=0.703 g=0.700
# 2/2 [==============================] - 0s 6ms/step
# Epoch>85, Batch153/390, d1=0.706, d2=0.694 g=0.698
# 2/2 [==============================] - 0s 7ms/step
# Epoch>85, Batch154/390, d1=0.703, d2=0.697 g=0.716
# 2/2 [==============================] - 0s 5ms/step
# Epoch>85, Batch155/390, d1=0.690, d2=0.687 g=0.715
# 2/2 [==============================] - 0s 4ms/step
# Epoch>85, Batch156/390, d1=0.697, d2=0.687 g=0.715
# 2/2 [==============================] - 0s 4ms/step
# Epoch>85, Batch157/390, d1=0.686, d2=0.687 g=0.702
# 2/2 [==============================] - 0s 9ms/step
# Epoch>85, Batch158/390, d1=0.689, d2=0.693 g=0.713
# 2/2 [==============================] - 0s 9ms/step
# Epoch>85, Batch159/390, d1=0.702, d2=0.690 g=0.708
# 2/2 [==============================] - 0s 9ms/step
# Epoch>85, Batch160/390, d1=0.691, d2=0.706 g=0.716
# 2/2 [==============================] - 0s 4ms/step
# Epoch>85, Batch161/390, d1=0.687, d2=0.695 g=0.710
# 2/2 [==============================] - 0s 7ms/step
# Epoch>85, Batch162/390, d1=0.681, d2=0.705 g=0.712
# 2/2 [==============================] - 0s 5ms/step
# Epoch>85, Batch163/390, d1=0.687, d2=0.679 g=0.714
# 2/2 [==============================] - 0s 7ms/step
# Epoch>85, Batch164/390, d1=0.671, d2=0.696 g=0.709
# 2/2 [==============================] - 0s 4ms/step
# Epoch>85, Batch165/390, d1=0.693, d2=0.695 g=0.717
# 2/2 [==============================] - 0s 7ms/step
# Epoch>85, Batch166/390, d1=0.688, d2=0.716 g=0.712
# 2/2 [==============================] - 0s 6ms/step
# Epoch>85, Batch167/390, d1=0.696, d2=0.701 g=0.713
# 2/2 [==============================] - 0s 6ms/step
# Epoch>85, Batch168/390, d1=0.699, d2=0.691 g=0.709
# 2/2 [==============================] - 0s 6ms/step
# Epoch>85, Batch169/390, d1=0.686, d2=0.689 g=0.710
# 2/2 [==============================] - 0s 10ms/step
# Epoch>85, Batch170/390, d1=0.689, d2=0.698 g=0.712
# 2/2 [==============================] - 0s 8ms/step
# Epoch>85, Batch171/390, d1=0.699, d2=0.705 g=0.719
# 2/2 [==============================] - 0s 7ms/step
# Epoch>85, Batch172/390, d1=0.706, d2=0.681 g=0.714
# 2/2 [==============================] - 0s 7ms/step
# Epoch>85, Batch173/390, d1=0.708, d2=0.706 g=0.719
# 2/2 [==============================] - 0s 5ms/step
# Epoch>85, Batch174/390, d1=0.717, d2=0.688 g=0.720
# 2/2 [==============================] - 0s 5ms/step
# Epoch>85, Batch175/390, d1=0.706, d2=0.684 g=0.716
# 2/2 [==============================] - 0s 15ms/step
# Epoch>85, Batch176/390, d1=0.706, d2=0.674 g=0.714
# 2/2 [==============================] - 0s 6ms/step
# Epoch>85, Batch177/390, d1=0.732, d2=0.671 g=0.717
# 2/2 [==============================] - 0s 7ms/step
# Epoch>85, Batch178/390, d1=0.708, d2=0.686 g=0.720
# 2/2 [==============================] - 0s 9ms/step
# Epoch>85, Batch179/390, d1=0.702, d2=0.686 g=0.715
# 2/2 [==============================] - 0s 16ms/step
# Epoch>85, Batch180/390, d1=0.699, d2=0.689 g=0.720
# 2/2 [==============================] - 0s 6ms/step
# Epoch>85, Batch181/390, d1=0.709, d2=0.688 g=0.718
# 2/2 [==============================] - 0s 6ms/step
# Epoch>85, Batch182/390, d1=0.699, d2=0.684 g=0.710
# 2/2 [==============================] - 0s 5ms/step
# Epoch>85, Batch183/390, d1=0.698, d2=0.719 g=0.708
# 2/2 [==============================] - 0s 12ms/step
# Epoch>85, Batch184/390, d1=0.670, d2=0.709 g=0.714
# 2/2 [==============================] - 0s 11ms/step
# Epoch>85, Batch185/390, d1=0.695, d2=0.681 g=0.715
# 2/2 [==============================] - 0s 5ms/step
# Epoch>85, Batch186/390, d1=0.688, d2=0.699 g=0.707
# 2/2 [==============================] - 0s 6ms/step
# Epoch>85, Batch187/390, d1=0.696, d2=0.693 g=0.712
# 2/2 [==============================] - 0s 7ms/step
# Epoch>85, Batch188/390, d1=0.705, d2=0.676 g=0.717
# 2/2 [==============================] - 0s 14ms/step
# Epoch>85, Batch189/390, d1=0.681, d2=0.686 g=0.705
# 2/2 [==============================] - 0s 11ms/step
# Epoch>85, Batch190/390, d1=0.698, d2=0.691 g=0.707
# 2/2 [==============================] - 0s 14ms/step
# Epoch>85, Batch191/390, d1=0.676, d2=0.713 g=0.700
# 2/2 [==============================] - 0s 5ms/step
# Epoch>85, Batch192/390, d1=0.699, d2=0.700 g=0.696
# 2/2 [==============================] - 0s 5ms/step
# Epoch>85, Batch193/390, d1=0.694, d2=0.695 g=0.688
# 2/2 [==============================] - 0s 11ms/step
# Epoch>85, Batch194/390, d1=0.696, d2=0.700 g=0.697
# 2/2 [==============================] - 0s 6ms/step
# Epoch>85, Batch195/390, d1=0.687, d2=0.709 g=0.706
# 2/2 [==============================] - 0s 10ms/step
# Epoch>85, Batch196/390, d1=0.708, d2=0.707 g=0.710
# 2/2 [==============================] - 0s 5ms/step
# Epoch>85, Batch197/390, d1=0.690, d2=0.716 g=0.714
# 2/2 [==============================] - 0s 10ms/step
# Epoch>85, Batch198/390, d1=0.712, d2=0.698 g=0.717
# 2/2 [==============================] - 0s 11ms/step
# Epoch>85, Batch199/390, d1=0.708, d2=0.699 g=0.712
# 2/2 [==============================] - 0s 7ms/step
# Epoch>85, Batch200/390, d1=0.702, d2=0.689 g=0.731
# 2/2 [==============================] - 0s 15ms/step
# Epoch>85, Batch201/390, d1=0.704, d2=0.674 g=0.730
# 2/2 [==============================] - 0s 8ms/step
# Epoch>85, Batch202/390, d1=0.698, d2=0.659 g=0.753
# 2/2 [==============================] - 0s 9ms/step
# Epoch>85, Batch203/390, d1=0.704, d2=0.667 g=0.752
# 2/2 [==============================] - 0s 5ms/step
# Epoch>85, Batch204/390, d1=0.704, d2=0.672 g=0.749
# 2/2 [==============================] - 0s 6ms/step
# Epoch>85, Batch205/390, d1=0.706, d2=0.672 g=0.730
# 2/2 [==============================] - 0s 5ms/step
# Epoch>85, Batch206/390, d1=0.701, d2=0.669 g=0.721
# 2/2 [==============================] - 0s 13ms/step
# Epoch>85, Batch207/390, d1=0.702, d2=0.681 g=0.716
# 2/2 [==============================] - 0s 10ms/step
# Epoch>85, Batch208/390, d1=0.724, d2=0.691 g=0.721
# 2/2 [==============================] - 0s 14ms/step
# Epoch>85, Batch209/390, d1=0.699, d2=0.684 g=0.724
# 2/2 [==============================] - 0s 11ms/step
# Epoch>85, Batch210/390, d1=0.700, d2=0.702 g=0.702
# 2/2 [==============================] - 0s 6ms/step
# Epoch>85, Batch211/390, d1=0.716, d2=0.694 g=0.702
# 2/2 [==============================] - 0s 12ms/step
# Epoch>85, Batch212/390, d1=0.688, d2=0.696 g=0.713
# 2/2 [==============================] - 0s 6ms/step
# Epoch>85, Batch213/390, d1=0.686, d2=0.714 g=0.709
# 2/2 [==============================] - 0s 13ms/step
# Epoch>85, Batch214/390, d1=0.691, d2=0.691 g=0.711
# 2/2 [==============================] - 0s 6ms/step
# Epoch>85, Batch215/390, d1=0.694, d2=0.687 g=0.701
# 2/2 [==============================] - 0s 6ms/step
# Epoch>85, Batch216/390, d1=0.682, d2=0.700 g=0.714
# 2/2 [==============================] - 0s 4ms/step
# Epoch>85, Batch217/390, d1=0.682, d2=0.687 g=0.711
# 2/2 [==============================] - 0s 6ms/step
# Epoch>85, Batch218/390, d1=0.674, d2=0.698 g=0.723
# 2/2 [==============================] - 0s 18ms/step
# Epoch>85, Batch219/390, d1=0.687, d2=0.701 g=0.695
# 2/2 [==============================] - 0s 9ms/step
# Epoch>85, Batch220/390, d1=0.692, d2=0.709 g=0.692
# 2/2 [==============================] - 0s 4ms/step
# Epoch>85, Batch221/390, d1=0.682, d2=0.723 g=0.708
# 2/2 [==============================] - 0s 12ms/step
# Epoch>85, Batch222/390, d1=0.689, d2=0.703 g=0.701
# 2/2 [==============================] - 0s 12ms/step
# Epoch>85, Batch223/390, d1=0.688, d2=0.698 g=0.703
# 2/2 [==============================] - 0s 4ms/step
# Epoch>85, Batch224/390, d1=0.681, d2=0.699 g=0.708
# 2/2 [==============================] - 0s 7ms/step
# Epoch>85, Batch225/390, d1=0.693, d2=0.704 g=0.704
# 2/2 [==============================] - 0s 6ms/step
# Epoch>85, Batch226/390, d1=0.699, d2=0.682 g=0.710
# 2/2 [==============================] - 0s 5ms/step
# Epoch>85, Batch227/390, d1=0.689, d2=0.698 g=0.717
# 2/2 [==============================] - 0s 10ms/step
# Epoch>85, Batch228/390, d1=0.690, d2=0.688 g=0.724
# 2/2 [==============================] - 0s 7ms/step
# Epoch>85, Batch229/390, d1=0.696, d2=0.698 g=0.724
# 2/2 [==============================] - 0s 4ms/step
# Epoch>85, Batch230/390, d1=0.715, d2=0.676 g=0.727
# 2/2 [==============================] - 0s 5ms/step
# Epoch>85, Batch231/390, d1=0.703, d2=0.683 g=0.729
# 2/2 [==============================] - 0s 5ms/step
# Epoch>85, Batch232/390, d1=0.712, d2=0.670 g=0.730
# 2/2 [==============================] - 0s 4ms/step
# Epoch>85, Batch233/390, d1=0.697, d2=0.672 g=0.732
# 2/2 [==============================] - 0s 4ms/step
# Epoch>85, Batch234/390, d1=0.694, d2=0.686 g=0.732
# 2/2 [==============================] - 0s 5ms/step
# Epoch>85, Batch235/390, d1=0.703, d2=0.681 g=0.724
# 2/2 [==============================] - 0s 4ms/step
# Epoch>85, Batch236/390, d1=0.699, d2=0.713 g=0.716
# 2/2 [==============================] - 0s 6ms/step
# Epoch>85, Batch237/390, d1=0.712, d2=0.692 g=0.721
# 2/2 [==============================] - 0s 9ms/step
# Epoch>85, Batch238/390, d1=0.707, d2=0.707 g=0.697
# 2/2 [==============================] - 0s 7ms/step
# Epoch>85, Batch239/390, d1=0.700, d2=0.699 g=0.700
# 2/2 [==============================] - 0s 6ms/step
# Epoch>85, Batch240/390, d1=0.697, d2=0.703 g=0.683
# 2/2 [==============================] - 0s 7ms/step
# Epoch>85, Batch241/390, d1=0.708, d2=0.700 g=0.700
# 2/2 [==============================] - 0s 5ms/step
# Epoch>85, Batch242/390, d1=0.701, d2=0.705 g=0.696
# 2/2 [==============================] - 0s 7ms/step
# Epoch>85, Batch243/390, d1=0.683, d2=0.695 g=0.704
# 2/2 [==============================] - 0s 7ms/step
# Epoch>85, Batch244/390, d1=0.687, d2=0.702 g=0.709
# 2/2 [==============================] - 0s 6ms/step
# Epoch>85, Batch245/390, d1=0.689, d2=0.703 g=0.704
# 2/2 [==============================] - 0s 5ms/step
# Epoch>85, Batch246/390, d1=0.682, d2=0.706 g=0.703
# 2/2 [==============================] - 0s 6ms/step
# Epoch>85, Batch247/390, d1=0.692, d2=0.713 g=0.717
# 2/2 [==============================] - 0s 9ms/step
# Epoch>85, Batch248/390, d1=0.679, d2=0.699 g=0.711
# 2/2 [==============================] - 0s 6ms/step
# Epoch>85, Batch249/390, d1=0.700, d2=0.694 g=0.705
# 2/2 [==============================] - 0s 9ms/step
# Epoch>85, Batch250/390, d1=0.706, d2=0.691 g=0.709
# 2/2 [==============================] - 0s 8ms/step
# Epoch>85, Batch251/390, d1=0.703, d2=0.700 g=0.709
# 2/2 [==============================] - 0s 6ms/step
# Epoch>85, Batch252/390, d1=0.690, d2=0.699 g=0.707
# 2/2 [==============================] - 0s 6ms/step
# Epoch>85, Batch253/390, d1=0.679, d2=0.712 g=0.710
# 2/2 [==============================] - 0s 10ms/step
# Epoch>85, Batch254/390, d1=0.698, d2=0.695 g=0.714
# 2/2 [==============================] - 0s 6ms/step
# Epoch>85, Batch255/390, d1=0.692, d2=0.700 g=0.718
# 2/2 [==============================] - 0s 6ms/step
# Epoch>85, Batch256/390, d1=0.688, d2=0.693 g=0.720
# 2/2 [==============================] - 0s 7ms/step
# Epoch>85, Batch257/390, d1=0.701, d2=0.704 g=0.720
# 2/2 [==============================] - 0s 6ms/step
# Epoch>85, Batch258/390, d1=0.691, d2=0.682 g=0.719
# 2/2 [==============================] - 0s 6ms/step
# Epoch>85, Batch259/390, d1=0.701, d2=0.689 g=0.731
# 2/2 [==============================] - 0s 6ms/step
# Epoch>85, Batch260/390, d1=0.701, d2=0.671 g=0.733
# 2/2 [==============================] - 0s 6ms/step
# Epoch>85, Batch261/390, d1=0.688, d2=0.672 g=0.722
# 2/2 [==============================] - 0s 9ms/step
# Epoch>85, Batch262/390, d1=0.697, d2=0.664 g=0.731
# 2/2 [==============================] - 0s 7ms/step
# Epoch>85, Batch263/390, d1=0.698, d2=0.696 g=0.719
# 2/2 [==============================] - 0s 7ms/step
# Epoch>85, Batch264/390, d1=0.693, d2=0.712 g=0.719
# 2/2 [==============================] - 0s 13ms/step
# Epoch>85, Batch265/390, d1=0.694, d2=0.685 g=0.723
# 2/2 [==============================] - 0s 18ms/step
# Epoch>85, Batch266/390, d1=0.693, d2=0.698 g=0.716
# 2/2 [==============================] - 0s 7ms/step
# Epoch>85, Batch267/390, d1=0.686, d2=0.698 g=0.727
# 2/2 [==============================] - 0s 8ms/step
# Epoch>85, Batch268/390, d1=0.707, d2=0.680 g=0.747
# 2/2 [==============================] - 0s 7ms/step
# Epoch>85, Batch269/390, d1=0.685, d2=0.697 g=0.732
# 2/2 [==============================] - 0s 15ms/step
# Epoch>85, Batch270/390, d1=0.720, d2=0.685 g=0.721
# 2/2 [==============================] - 0s 18ms/step
# Epoch>85, Batch271/390, d1=0.692, d2=0.687 g=0.709
# 2/2 [==============================] - 0s 6ms/step
# Epoch>85, Batch272/390, d1=0.703, d2=0.707 g=0.715
# 2/2 [==============================] - 0s 13ms/step
# Epoch>85, Batch273/390, d1=0.696, d2=0.707 g=0.711
# 2/2 [==============================] - 0s 13ms/step
# Epoch>85, Batch274/390, d1=0.717, d2=0.706 g=0.706
# 2/2 [==============================] - 0s 5ms/step
# Epoch>85, Batch275/390, d1=0.696, d2=0.692 g=0.695
# 2/2 [==============================] - 0s 12ms/step
# Epoch>85, Batch276/390, d1=0.692, d2=0.699 g=0.719
# 2/2 [==============================] - 0s 7ms/step
# Epoch>85, Batch277/390, d1=0.709, d2=0.698 g=0.714
# 2/2 [==============================] - 0s 4ms/step
# Epoch>85, Batch278/390, d1=0.684, d2=0.705 g=0.731
# 2/2 [==============================] - 0s 15ms/step
# Epoch>85, Batch279/390, d1=0.691, d2=0.676 g=0.727
# 2/2 [==============================] - 0s 7ms/step
# Epoch>85, Batch280/390, d1=0.685, d2=0.685 g=0.734
# 2/2 [==============================] - 0s 10ms/step
# Epoch>85, Batch281/390, d1=0.683, d2=0.697 g=0.723
# 2/2 [==============================] - 0s 4ms/step
# Epoch>85, Batch282/390, d1=0.690, d2=0.708 g=0.732
# 2/2 [==============================] - 0s 7ms/step
# Epoch>85, Batch283/390, d1=0.703, d2=0.667 g=0.750
# 2/2 [==============================] - 0s 5ms/step
# Epoch>85, Batch284/390, d1=0.700, d2=0.662 g=0.756
# 2/2 [==============================] - 0s 5ms/step
# Epoch>85, Batch285/390, d1=0.690, d2=0.701 g=0.720
# 2/2 [==============================] - 0s 9ms/step
# Epoch>85, Batch286/390, d1=0.699, d2=0.712 g=0.705
# 2/2 [==============================] - 0s 5ms/step
# Epoch>85, Batch287/390, d1=0.686, d2=0.707 g=0.752
# 2/2 [==============================] - 0s 5ms/step
# Epoch>85, Batch288/390, d1=0.666, d2=0.663 g=0.782
# 2/2 [==============================] - 0s 5ms/step
# Epoch>85, Batch289/390, d1=0.700, d2=0.678 g=0.725
# 2/2 [==============================] - 0s 5ms/step
# Epoch>85, Batch290/390, d1=0.693, d2=0.703 g=0.715
# 2/2 [==============================] - 0s 15ms/step
# Epoch>85, Batch291/390, d1=0.692, d2=0.708 g=0.701
# 2/2 [==============================] - 0s 9ms/step
# Epoch>85, Batch292/390, d1=0.674, d2=0.704 g=0.718
# 2/2 [==============================] - 0s 5ms/step
# Epoch>85, Batch293/390, d1=0.687, d2=0.691 g=0.732
# 2/2 [==============================] - 0s 10ms/step
# Epoch>85, Batch294/390, d1=0.686, d2=0.681 g=0.731
# 2/2 [==============================] - 0s 5ms/step
# Epoch>85, Batch295/390, d1=0.683, d2=0.661 g=0.723
# 2/2 [==============================] - 0s 5ms/step
# Epoch>85, Batch296/390, d1=0.691, d2=0.690 g=0.727
# 2/2 [==============================] - 0s 5ms/step
# Epoch>85, Batch297/390, d1=0.696, d2=0.688 g=0.721
# 2/2 [==============================] - 0s 8ms/step
# Epoch>85, Batch298/390, d1=0.712, d2=0.692 g=0.722
# 2/2 [==============================] - 0s 6ms/step
# Epoch>85, Batch299/390, d1=0.702, d2=0.686 g=0.712
# 2/2 [==============================] - 0s 6ms/step
# Epoch>85, Batch300/390, d1=0.686, d2=0.685 g=0.717
# 2/2 [==============================] - 0s 8ms/step
# Epoch>85, Batch301/390, d1=0.702, d2=0.725 g=0.703
# 2/2 [==============================] - 0s 4ms/step
# Epoch>85, Batch302/390, d1=0.691, d2=0.706 g=0.695
# 2/2 [==============================] - 0s 10ms/step
# Epoch>85, Batch303/390, d1=0.716, d2=0.703 g=0.704
# 2/2 [==============================] - 0s 4ms/step
# Epoch>85, Batch304/390, d1=0.695, d2=0.702 g=0.709
# 2/2 [==============================] - 0s 9ms/step
# Epoch>85, Batch305/390, d1=0.691, d2=0.711 g=0.710
# 2/2 [==============================] - 0s 10ms/step
# Epoch>85, Batch306/390, d1=0.688, d2=0.692 g=0.703
# 2/2 [==============================] - 0s 9ms/step
# Epoch>85, Batch307/390, d1=0.688, d2=0.706 g=0.702
# 2/2 [==============================] - 0s 7ms/step
# Epoch>85, Batch308/390, d1=0.698, d2=0.690 g=0.709
# 2/2 [==============================] - 0s 10ms/step
# Epoch>85, Batch309/390, d1=0.693, d2=0.687 g=0.717
# 2/2 [==============================] - 0s 4ms/step
# ...
# Epoch>90, Batch236/390, d1=0.687, d2=0.670 g=0.750
# 2/2 [==============================] - 0s 5ms/step
# Epoch>90, Batch237/390, d1=0.687, d2=0.648 g=0.745
# 2/2 [==============================] - 0s 5ms/step
# Epoch>90, Batch238/390, d1=0.699, d2=0.657 g=0.751
# 2/2 [==============================] - 0s 5ms/step
# Epoch>90, Batch239/390, d1=0.706, d2=0.666 g=0.737
# 2/2 [==============================] - 0s 5ms/step
# Epoch>90, Batch240/390, d1=0.718, d2=0.676 g=0.725
# 2/2 [==============================] - 0s 6ms/step
# Epoch>90, Batch241/390, d1=0.700, d2=0.697 g=0.714
# 2/2 [==============================] - 0s 5ms/step
# Epoch>90, Batch242/390, d1=0.702, d2=0.690 g=0.709
# 2/2 [==============================] - 0s 4ms/step
# Epoch>90, Batch243/390, d1=0.713, d2=0.691 g=0.712
# 2/2 [==============================] - 0s 16ms/step
# Epoch>90, Batch244/390, d1=0.706, d2=0.683 g=0.728
# 2/2 [==============================] - 0s 5ms/step
# Epoch>90, Batch245/390, d1=0.695, d2=0.694 g=0.725
# 2/2 [==============================] - 0s 5ms/step
# Epoch>90, Batch246/390, d1=0.695, d2=0.692 g=0.740
# 2/2 [==============================] - 0s 5ms/step
# Epoch>90, Batch247/390, d1=0.696, d2=0.687 g=0.695
# 2/2 [==============================] - 0s 5ms/step
# Epoch>90, Batch248/390, d1=0.700, d2=0.726 g=0.717
# 2/2 [==============================] - 0s 7ms/step
# Epoch>90, Batch249/390, d1=0.710, d2=0.716 g=0.706
# 2/2 [==============================] - 0s 5ms/step
# Epoch>90, Batch250/390, d1=0.706, d2=0.699 g=0.715
# 2/2 [==============================] - 0s 4ms/step
# Epoch>90, Batch251/390, d1=0.712, d2=0.682 g=0.726
# 2/2 [==============================] - 0s 4ms/step
# Epoch>90, Batch252/390, d1=0.690, d2=0.678 g=0.723
# 2/2 [==============================] - 0s 5ms/step
# Epoch>90, Batch253/390, d1=0.702, d2=0.712 g=0.709
# 2/2 [==============================] - 0s 5ms/step
# Epoch>90, Batch254/390, d1=0.683, d2=0.715 g=0.708
# 2/2 [==============================] - 0s 11ms/step
# Epoch>90, Batch255/390, d1=0.697, d2=0.715 g=0.706
# 2/2 [==============================] - 0s 9ms/step
# Epoch>90, Batch256/390, d1=0.684, d2=0.696 g=0.712
# 2/2 [==============================] - 0s 5ms/step
# Epoch>90, Batch257/390, d1=0.705, d2=0.683 g=0.723
# 2/2 [==============================] - 0s 9ms/step
# Epoch>90, Batch258/390, d1=0.705, d2=0.691 g=0.721
# 2/2 [==============================] - 0s 10ms/step
# Epoch>90, Batch259/390, d1=0.706, d2=0.681 g=0.724
# 2/2 [==============================] - 0s 12ms/step
# Epoch>90, Batch260/390, d1=0.704, d2=0.680 g=0.723
# 2/2 [==============================] - 0s 6ms/step
# Epoch>90, Batch261/390, d1=0.691, d2=0.696 g=0.709
# 2/2 [==============================] - 0s 4ms/step
# Epoch>90, Batch262/390, d1=0.674, d2=0.687 g=0.719
# 2/2 [==============================] - 0s 10ms/step
# Epoch>90, Batch263/390, d1=0.690, d2=0.686 g=0.718
# 2/2 [==============================] - 0s 12ms/step
# Epoch>90, Batch264/390, d1=0.696, d2=0.677 g=0.709
# 2/2 [==============================] - 0s 5ms/step
# Epoch>90, Batch265/390, d1=0.669, d2=0.697 g=0.694
# 2/2 [==============================] - 0s 6ms/step
# Epoch>90, Batch266/390, d1=0.689, d2=0.699 g=0.690
# 2/2 [==============================] - 0s 6ms/step
# Epoch>90, Batch267/390, d1=0.686, d2=0.738 g=0.695
# 2/2 [==============================] - 0s 12ms/step
# Epoch>90, Batch268/390, d1=0.673, d2=0.727 g=0.675
# 2/2 [==============================] - 0s 6ms/step
# Epoch>90, Batch269/390, d1=0.678, d2=0.718 g=0.705
# 2/2 [==============================] - 0s 5ms/step
# Epoch>90, Batch270/390, d1=0.696, d2=0.697 g=0.711
# 2/2 [==============================] - 0s 5ms/step
# Epoch>90, Batch271/390, d1=0.699, d2=0.694 g=0.722
# 2/2 [==============================] - 0s 4ms/step
# Epoch>90, Batch272/390, d1=0.704, d2=0.698 g=0.733
# 2/2 [==============================] - 0s 6ms/step
# Epoch>90, Batch273/390, d1=0.711, d2=0.682 g=0.758
# 2/2 [==============================] - 0s 13ms/step
# Epoch>90, Batch274/390, d1=0.692, d2=0.674 g=0.738
# 2/2 [==============================] - 0s 10ms/step
# Epoch>90, Batch275/390, d1=0.686, d2=0.684 g=0.741
# 2/2 [==============================] - 0s 9ms/step
# Epoch>90, Batch276/390, d1=0.697, d2=0.691 g=0.740
# 2/2 [==============================] - 0s 5ms/step
# Epoch>90, Batch277/390, d1=0.691, d2=0.686 g=0.742
# 2/2 [==============================] - 0s 6ms/step
# Epoch>90, Batch278/390, d1=0.707, d2=0.663 g=0.768
# 2/2 [==============================] - 0s 5ms/step
# Epoch>90, Batch279/390, d1=0.697, d2=0.656 g=0.789
# 2/2 [==============================] - 0s 10ms/step
# Epoch>90, Batch280/390, d1=0.693, d2=0.654 g=0.753
# 2/2 [==============================] - 0s 11ms/step
# Epoch>90, Batch281/390, d1=0.678, d2=0.710 g=0.713
# 2/2 [==============================] - 0s 4ms/step
# Epoch>90, Batch282/390, d1=0.706, d2=0.739 g=0.683
# 2/2 [==============================] - 0s 4ms/step
# Epoch>90, Batch283/390, d1=0.725, d2=0.739 g=0.753
# 2/2 [==============================] - 0s 6ms/step
# Epoch>90, Batch284/390, d1=0.698, d2=0.658 g=0.791
# 2/2 [==============================] - 0s 4ms/step
# Epoch>90, Batch285/390, d1=0.701, d2=0.695 g=0.704
# 2/2 [==============================] - 0s 4ms/step
# Epoch>90, Batch286/390, d1=0.707, d2=0.698 g=0.702
# 2/2 [==============================] - 0s 4ms/step
# Epoch>90, Batch287/390, d1=0.698, d2=0.692 g=0.729
# 2/2 [==============================] - 0s 10ms/step
# Epoch>90, Batch288/390, d1=0.698, d2=0.672 g=0.755
# 2/2 [==============================] - 0s 9ms/step
# Epoch>90, Batch289/390, d1=0.688, d2=0.681 g=0.723
# 2/2 [==============================] - 0s 13ms/step
# Epoch>90, Batch290/390, d1=0.687, d2=0.693 g=0.726
# 2/2 [==============================] - 0s 5ms/step
# Epoch>90, Batch291/390, d1=0.695, d2=0.696 g=0.721
# 2/2 [==============================] - 0s 13ms/step
# Epoch>90, Batch292/390, d1=0.698, d2=0.686 g=0.715
# 2/2 [==============================] - 0s 6ms/step
# Epoch>90, Batch293/390, d1=0.701, d2=0.681 g=0.702
# 2/2 [==============================] - 0s 7ms/step
# Epoch>90, Batch294/390, d1=0.685, d2=0.697 g=0.728
# 2/2 [==============================] - 0s 10ms/step
# Epoch>90, Batch295/390, d1=0.698, d2=0.681 g=0.714
# 2/2 [==============================] - 0s 17ms/step
# Epoch>90, Batch296/390, d1=0.697, d2=0.694 g=0.717
# 2/2 [==============================] - 0s 10ms/step
# Epoch>90, Batch297/390, d1=0.702, d2=0.689 g=0.714
# 2/2 [==============================] - 0s 6ms/step
# Epoch>90, Batch298/390, d1=0.691, d2=0.712 g=0.711
# 2/2 [==============================] - 0s 8ms/step
# Epoch>90, Batch299/390, d1=0.692, d2=0.691 g=0.712
# 2/2 [==============================] - 0s 5ms/step
# Epoch>90, Batch300/390, d1=0.697, d2=0.700 g=0.712
# 2/2 [==============================] - 0s 10ms/step
# Epoch>90, Batch301/390, d1=0.678, d2=0.703 g=0.703
# 2/2 [==============================] - 0s 6ms/step
# Epoch>90, Batch302/390, d1=0.705, d2=0.699 g=0.689
# 2/2 [==============================] - 0s 9ms/step
# Epoch>90, Batch303/390, d1=0.697, d2=0.725 g=0.705
# 2/2 [==============================] - 0s 10ms/step
# Epoch>90, Batch304/390, d1=0.702, d2=0.695 g=0.704
# 2/2 [==============================] - 0s 6ms/step
# Epoch>90, Batch305/390, d1=0.688, d2=0.699 g=0.707
# 2/2 [==============================] - 0s 11ms/step
# Epoch>90, Batch306/390, d1=0.699, d2=0.689 g=0.699
# 2/2 [==============================] - 0s 5ms/step
# Epoch>90, Batch307/390, d1=0.690, d2=0.697 g=0.689
# 2/2 [==============================] - 0s 6ms/step
# Epoch>90, Batch308/390, d1=0.673, d2=0.719 g=0.698
# 2/2 [==============================] - 0s 6ms/step
# Epoch>90, Batch309/390, d1=0.667, d2=0.708 g=0.711
# 2/2 [==============================] - 0s 5ms/step
# Epoch>90, Batch310/390, d1=0.680, d2=0.699 g=0.692
# 2/2 [==============================] - 0s 7ms/step
# Epoch>90, Batch311/390, d1=0.690, d2=0.705 g=0.703
# 2/2 [==============================] - 0s 6ms/step
# Epoch>90, Batch312/390, d1=0.681, d2=0.708 g=0.702
# 2/2 [==============================] - 0s 12ms/step
# Epoch>90, Batch313/390, d1=0.691, d2=0.689 g=0.699
# 2/2 [==============================] - 0s 6ms/step
# Epoch>90, Batch314/390, d1=0.678, d2=0.718 g=0.712
# 2/2 [==============================] - 0s 6ms/step
# Epoch>90, Batch315/390, d1=0.681, d2=0.708 g=0.693
# 2/2 [==============================] - 0s 9ms/step
# Epoch>90, Batch316/390, d1=0.687, d2=0.718 g=0.705
# 2/2 [==============================] - 0s 9ms/step
# Epoch>90, Batch317/390, d1=0.698, d2=0.711 g=0.711
# 2/2 [==============================] - 0s 4ms/step
# Epoch>90, Batch318/390, d1=0.695, d2=0.689 g=0.707
# 2/2 [==============================] - 0s 5ms/step
# Epoch>90, Batch319/390, d1=0.697, d2=0.684 g=0.708
# 2/2 [==============================] - 0s 10ms/step
# Epoch>90, Batch320/390, d1=0.692, d2=0.694 g=0.724
# 2/2 [==============================] - 0s 4ms/step
# Epoch>90, Batch321/390, d1=0.711, d2=0.688 g=0.724
# 2/2 [==============================] - 0s 5ms/step
# Epoch>90, Batch322/390, d1=0.715, d2=0.687 g=0.717
# 2/2 [==============================] - 0s 14ms/step
# Epoch>90, Batch323/390, d1=0.704, d2=0.684 g=0.721
# 2/2 [==============================] - 0s 5ms/step
# Epoch>90, Batch324/390, d1=0.704, d2=0.681 g=0.717
# 2/2 [==============================] - 0s 6ms/step
# Epoch>90, Batch325/390, d1=0.705, d2=0.687 g=0.721
# 2/2 [==============================] - 0s 5ms/step
# Epoch>90, Batch326/390, d1=0.707, d2=0.689 g=0.711
# 2/2 [==============================] - 0s 6ms/step
# Epoch>90, Batch327/390, d1=0.693, d2=0.689 g=0.709
# 2/2 [==============================] - 0s 4ms/step
# Epoch>90, Batch328/390, d1=0.705, d2=0.696 g=0.710
# 2/2 [==============================] - 0s 7ms/step
# Epoch>90, Batch329/390, d1=0.704, d2=0.691 g=0.705
# 2/2 [==============================] - 0s 9ms/step
# Epoch>90, Batch330/390, d1=0.710, d2=0.684 g=0.718
# 2/2 [==============================] - 0s 10ms/step
# Epoch>90, Batch331/390, d1=0.698, d2=0.707 g=0.727
# 2/2 [==============================] - 0s 6ms/step
# Epoch>90, Batch332/390, d1=0.693, d2=0.668 g=0.711
# 2/2 [==============================] - 0s 10ms/step
# Epoch>90, Batch333/390, d1=0.708, d2=0.680 g=0.714
# 2/2 [==============================] - 0s 10ms/step
# Epoch>90, Batch334/390, d1=0.691, d2=0.689 g=0.719
# 2/2 [==============================] - 0s 4ms/step
# Epoch>90, Batch335/390, d1=0.707, d2=0.687 g=0.725
# 2/2 [==============================] - 0s 14ms/step
# Epoch>90, Batch336/390, d1=0.699, d2=0.669 g=0.733
# 2/2 [==============================] - 0s 4ms/step
# Epoch>90, Batch337/390, d1=0.702, d2=0.670 g=0.725
# 2/2 [==============================] - 0s 5ms/step
# Epoch>90, Batch338/390, d1=0.703, d2=0.681 g=0.728
# 2/2 [==============================] - 0s 4ms/step
# Epoch>90, Batch339/390, d1=0.684, d2=0.681 g=0.722
# 2/2 [==============================] - 0s 7ms/step
# Epoch>90, Batch340/390, d1=0.678, d2=0.700 g=0.712
# 2/2 [==============================] - 0s 5ms/step
# Epoch>90, Batch341/390, d1=0.694, d2=0.696 g=0.709
# 2/2 [==============================] - 0s 10ms/step
# Epoch>90, Batch342/390, d1=0.696, d2=0.711 g=0.716
# 2/2 [==============================] - 0s 5ms/step
# Epoch>90, Batch343/390, d1=0.697, d2=0.709 g=0.703
# 2/2 [==============================] - 0s 5ms/step
# Epoch>90, Batch344/390, d1=0.692, d2=0.703 g=0.716
# 2/2 [==============================] - 0s 11ms/step
# Epoch>90, Batch345/390, d1=0.694, d2=0.687 g=0.713
# 2/2 [==============================] - 0s 14ms/step
# Epoch>90, Batch346/390, d1=0.705, d2=0.705 g=0.700
# 2/2 [==============================] - 0s 13ms/step
# Epoch>90, Batch347/390, d1=0.693, d2=0.726 g=0.712
# 2/2 [==============================] - 0s 16ms/step
# Epoch>90, Batch348/390, d1=0.714, d2=0.713 g=0.699
# 2/2 [==============================] - 0s 9ms/step
# Epoch>90, Batch349/390, d1=0.687, d2=0.702 g=0.713
# 2/2 [==============================] - 0s 13ms/step
# Epoch>90, Batch350/390, d1=0.705, d2=0.689 g=0.711
# 2/2 [==============================] - 0s 8ms/step
# Epoch>90, Batch351/390, d1=0.705, d2=0.708 g=0.726
# 2/2 [==============================] - 0s 6ms/step
# Epoch>90, Batch352/390, d1=0.709, d2=0.681 g=0.721
# 2/2 [==============================] - 0s 6ms/step
# Epoch>90, Batch353/390, d1=0.707, d2=0.678 g=0.718
# 2/2 [==============================] - 0s 10ms/step
# Epoch>90, Batch354/390, d1=0.702, d2=0.670 g=0.711
# 2/2 [==============================] - 0s 5ms/step
# Epoch>90, Batch355/390, d1=0.701, d2=0.684 g=0.722
# 2/2 [==============================] - 0s 5ms/step
# Epoch>90, Batch356/390, d1=0.709, d2=0.699 g=0.708
# 2/2 [==============================] - 0s 11ms/step
# Epoch>90, Batch357/390, d1=0.684, d2=0.687 g=0.700
# 2/2 [==============================] - 0s 8ms/step
# Epoch>90, Batch358/390, d1=0.695, d2=0.697 g=0.706
# 2/2 [==============================] - 0s 14ms/step
# Epoch>90, Batch359/390, d1=0.695, d2=0.686 g=0.711
# 2/2 [==============================] - 0s 13ms/step
# Epoch>90, Batch360/390, d1=0.697, d2=0.695 g=0.709
# 2/2 [==============================] - 0s 10ms/step
# Epoch>90, Batch361/390, d1=0.699, d2=0.680 g=0.717
# 2/2 [==============================] - 0s 11ms/step
# Epoch>90, Batch362/390, d1=0.688, d2=0.682 g=0.711
# 2/2 [==============================] - 0s 5ms/step
# Epoch>90, Batch363/390, d1=0.691, d2=0.694 g=0.707
# 2/2 [==============================] - 0s 6ms/step
# Epoch>90, Batch364/390, d1=0.693, d2=0.680 g=0.714
# 2/2 [==============================] - 0s 11ms/step
# Epoch>90, Batch365/390, d1=0.698, d2=0.694 g=0.715
# 2/2 [==============================] - 0s 6ms/step
# Epoch>90, Batch366/390, d1=0.682, d2=0.691 g=0.703
# 2/2 [==============================] - 0s 6ms/step
# Epoch>90, Batch367/390, d1=0.694, d2=0.696 g=0.708
# 2/2 [==============================] - 0s 7ms/step
# Epoch>90, Batch368/390, d1=0.684, d2=0.690 g=0.703
# 2/2 [==============================] - 0s 6ms/step
# Epoch>90, Batch369/390, d1=0.681, d2=0.699 g=0.701
# 2/2 [==============================] - 0s 13ms/step
# Epoch>90, Batch370/390, d1=0.685, d2=0.699 g=0.700
# 2/2 [==============================] - 0s 6ms/step
# Epoch>90, Batch371/390, d1=0.689, d2=0.700 g=0.698
# 2/2 [==============================] - 0s 5ms/step
# Epoch>90, Batch372/390, d1=0.699, d2=0.697 g=0.702
# 2/2 [==============================] - 0s 6ms/step
# Epoch>90, Batch373/390, d1=0.687, d2=0.701 g=0.701
# 2/2 [==============================] - 0s 6ms/step
# Epoch>90, Batch374/390, d1=0.700, d2=0.689 g=0.711
# 2/2 [==============================] - 0s 13ms/step
# Epoch>90, Batch375/390, d1=0.701, d2=0.697 g=0.717
# 2/2 [==============================] - 0s 10ms/step
# Epoch>90, Batch376/390, d1=0.705, d2=0.701 g=0.721
# 2/2 [==============================] - 0s 8ms/step
# Epoch>90, Batch377/390, d1=0.689, d2=0.685 g=0.728
# 2/2 [==============================] - 0s 6ms/step
# Epoch>90, Batch378/390, d1=0.706, d2=0.681 g=0.734
# 2/2 [==============================] - 0s 5ms/step
# Epoch>90, Batch379/390, d1=0.701, d2=0.677 g=0.728
# 2/2 [==============================] - 0s 5ms/step
# Epoch>90, Batch380/390, d1=0.690, d2=0.683 g=0.722
# 2/2 [==============================] - 0s 5ms/step
# Epoch>90, Batch381/390, d1=0.694, d2=0.677 g=0.738
# 2/2 [==============================] - 0s 4ms/step
# Epoch>90, Batch382/390, d1=0.704, d2=0.686 g=0.746
# 2/2 [==============================] - 0s 5ms/step
# Epoch>90, Batch383/390, d1=0.701, d2=0.673 g=0.740
# 2/2 [==============================] - 0s 4ms/step
# Epoch>90, Batch384/390, d1=0.705, d2=0.685 g=0.725
# 2/2 [==============================] - 0s 6ms/step
# Epoch>90, Batch385/390, d1=0.712, d2=0.678 g=0.732
# 2/2 [==============================] - 0s 5ms/step
# Epoch>90, Batch386/390, d1=0.708, d2=0.676 g=0.722
# 2/2 [==============================] - 0s 8ms/step
# Epoch>90, Batch387/390, d1=0.725, d2=0.676 g=0.729
# 2/2 [==============================] - 0s 13ms/step
# Epoch>90, Batch388/390, d1=0.707, d2=0.700 g=0.706
# 2/2 [==============================] - 0s 12ms/step
# Epoch>90, Batch389/390, d1=0.715, d2=0.680 g=0.711
# 2/2 [==============================] - 0s 6ms/step
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch>90, Batch390/390, d1=0.713, d2=0.689 g=0.699

# %%
# Now, let us load the generator model and generate images
# Lod the trained model and generate a few images
from numpy import asarray
from numpy.random import randn
from numpy.random import randint
from keras.models import load_model
import numpy as np
#

#Note: CIFAR10 classes are: airplane, automobile, bird, cat, deer, dog, frog, horse,
# ship, truck

# load model
model = load_model('/content/cifar_conditional_generator_25epochs.h5')

# generate multiple images

latent_points, labels = generate_latent_points(100, 100)
# specify labels - generate 10 sets of labels each gping from 0 to 9
labels = asarray([x for _ in range(10) for x in range(10)])
# generate images
X  = model.predict([latent_points, labels])
# scale from [-1,1] to [0,1]
X = (X + 1) / 2.0
X = (X*255).astype(np.uint8)
# plot the result (10 sets of images, all images in a column should be of same class in the plot)
# Plot generated images
def show_plot(examples, n):
	for i in range(n * n):
		plt.subplot(n, n, 1 + i)
		plt.axis('off')
		plt.imshow(examples[i, :, :, :])
	plt.show()

show_plot(X, 10)
# Out:
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# 4/4 [==============================] - 0s 83ms/step
